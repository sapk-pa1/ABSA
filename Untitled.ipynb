# %%
#importing required Libraries 
import xml.etree.ElementTree as ET

# %%
tree = ET.parse('./datasets/ABSA-15_Laptops_Train_Data.xml')
root = tree.getroot()

# %%
root.tag
# Out:
# 'Reviews'

# %%
root.attrib
# Out:
# {}

# %%
for child in root:
    print(child.tag, child.attrib)
# Out:
# Review {'rid': '79'}
# Review {'rid': '10'}
# Review {'rid': '264'}
# Review {'rid': '24'}
# Review {'rid': '277'}
# Review {'rid': '178'}
# Review {'rid': '77'}
# Review {'rid': '342'}
# Review {'rid': '348'}
# Review {'rid': '347'}
# Review {'rid': '339'}
# Review {'rid': '273'}
# Review {'rid': '240'}
# Review {'rid': '243'}
# Review {'rid': '285'}
# Review {'rid': '212'}
# Review {'rid': '93'}
# Review {'rid': '252'}
# Review {'rid': '19'}
# Review {'rid': '165'}
# Review {'rid': '111'}
# Review {'rid': '292'}
# Review {'rid': '359'}
# Review {'rid': '95'}
# Review {'rid': '360'}
# Review {'rid': '66'}
# Review {'rid': '384'}
# Review {'rid': '54'}
# Review {'rid': '176'}
# Review {'rid': '59'}
# Review {'rid': '170'}
# Review {'rid': '90'}
# Review {'rid': '220'}
# Review {'rid': '278'}
# Review {'rid': '135'}
# Review {'rid': '159'}
# Review {'rid': '57'}
# Review {'rid': '76'}
# Review {'rid': '28'}
# Review {'rid': '267'}
# Review {'rid': '132'}
# Review {'rid': '167'}
# ...

# %%
[elem.tag for elem in root.iter()]
# Out:
# ['Reviews',
#  'Review',
#  'sentences',
#  'sentence',
#  'text',
#  'sentence',
#  'text',
#  'Opinions',
#  'Opinion',
#  'sentence',
#  'text',
#  'Opinions',
#  'Opinion',
#  'sentence',
#  'text',
#  'Opinions',
#  'Opinion',
#  'Opinion',
#  'sentence',
#  'text',
#  'Opinions',
#  'Opinion',
#  'sentence',
#  'text',
#  'Opinions',
#  'Opinion',
#  'Opinion',
#  'sentence',
#  'text',
#  'Opinions',
#  'Opinion',
#  'sentence',
#  'text',
#  'sentence',
#  'text',
#  'Opinions',
#  'Opinion',
#  'Opinion',
#  'Review',
#  'sentences',
#  'sentence',
#  'text',
#  'Opinions',
#  'Opinion',
#  'Opinion',
#  'sentence',
#  'text',
#  'Opinions',
#  'Opinion',
#  'sentence',
#  'text',
#  'Opinions',
#  'Opinion',
#  'Opinion',
#  'Review',
#  'sentences',
#  'sentence',
#  'text',
#  'sentence',
#  'text',
#  'Opinions',
#  'Opinion',
#  'Opinion',
#  'Opinion',
#  'sentence',
#  'text',
#  'Opinions',
#  'Opinion',
#  'Opinion',
#  'Opinion',
#  'sentence',
#  'text',
# ...
